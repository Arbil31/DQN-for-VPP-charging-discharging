# %% [markdown]
# Import Libaries

# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import random
import tensorflow as tf

# %% [markdown]
# Optiimize GPU memory Utilization

# %%
### Limiting GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
print('Available Physical GPUs=>'+str(gpus))
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print('Configured Logical GPUs=>'+str(logical_gpus))
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# Available Physical GPUs=>[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Physical devices cannot be modified after being initialized

# %% [markdown]
# Define Custom environment for VPP charging/ discharging scheduling

# %%
class VPP(Env):
    def __init__(self):
        #Environment parameters
        self.state = random.randint(0, 100)  #current soc
        self.max_soc = 95
        self.min_soc = 15
        self.generation = random.randint(0, 100)
        self.demand = random.randint(5, 75)

        #Action space (charge, discharge, isolate)
        self.action_space = Discrete(3)

        #State_space
        self.observation_space = Box(low = np.array([0]), high = np.array([100]))

        #Set episode length
        self.episode_length = 900


    #Define steps based on action
    def step(self, action):
        if action == 0:    #charge
            self.state = self.state+1
        elif action == 1:   #discharge
            self.state = self.state-1
        # Action 2 : Isolate (no effect on SoC)

        self.episode_length -= 1

    
        #Define the reward based on generation, demand, and current soc level
        if (self.generation > self.demand) & self.state>=self.min_soc & self.state<=self.max_soc:
            reward = 1.0
        else:
            reward = -1.0

        #Check if the episode is done
        if self.episode_length<=0:
            done = True
        else:
            done = False

        info = {}

        return self.state, reward, done, info
    
    def render(self):
        pass

    def reset(self):
        self.state = random.randint(0, 100)
        self.episode_length = 900
        return self.state

# %% [markdown]
# Calling the VPP environment

# %%
env = VPP()

# %%
#Random action in each step
print(env.action_space.sample())

#dimention of state
print(env.observation_space.shape[0])

#Random initial temp
print(env.state)
# Out:
# 2
# 1
# 8

# %%
action = env.action_space.sample()
state, reward, done, info = env.step(action)
print(state, reward, done, info)
# Out:
# 8 -1.0 False {}

# %%
ep = []
scr = []
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        action = env.action_space.sample()
        state, reward, done, info = env.step(action)
        score += reward
    ep.append(int(episode))
    scr.append(score)
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-86.0
# Episode:2 Score:-62.0
# Episode:3 Score:-94.0
# Episode:4 Score:-82.0
# Episode:5 Score:-100.0
# Episode:6 Score:-86.0
# Episode:7 Score:-98.0
# Episode:8 Score:-36.0
# Episode:9 Score:-94.0
# Episode:10 Score:-76.0

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20,3))

plt.plot(ep, scr)
plt.xlabel('Number of episodes')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# Import libraries for DQN

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
states = env.observation_space.shape
actions = env.action_space.n

# %%
print(states, actions)
# Out:
# (1,) 3

# %% [markdown]
# Build Model free DQN

# %%
def build_model(states,actions):
    model = Sequential()
    model.add(Dense(24, activation = 'relu', input_shape = states))
    model.add(Dense(24, activation = 'relu'))
    model.add(Dense(actions, activation = 'linear'))
    return model

# %%
del model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 24)                48
#
#  dense_4 (Dense)             (None, 24)                600
#
#  dense_5 (Dense)             (None, 3)                 75
#
# =================================================================
# Total params: 723
# Trainable params: 723
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Import Libraries for DQN Agent

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %% [markdown]
# Building the DQN Agent

# %%
def  build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit = 50000, window_length = 1)
    dqn = DQNAgent(model = model, memory = memory, policy = policy,
                   nb_actions = actions, nb_steps_warmup = 10, target_model_update = 1e-2)
    return dqn

# %% [markdown]
# Training the model free DQN Agent for VPP environment

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(lr = 1e-3), metrics = ['mae'])
dqn.fit(env, nb_steps = 50000, visualize = False,  verbose = 1)
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# c:\Users\Arbil\anaconda3\envs\py37gpu\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#     1/10000 [..............................] - ETA: 2:19:49 - reward: -1.0000
# c:\Users\Arbil\anaconda3\envs\py37gpu\lib\site-packages\rl\memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.4662
# 100 episodes - episode_reward: -46.620 [-100.000, 86.000] - loss: 1.398 - mae: 9.364 - mean_q: -7.346
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: -0.3306
# 100 episodes - episode_reward: -33.060 [-96.000, 92.000] - loss: 3.587 - mae: 14.286 - mean_q: 1.735
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 127s 13ms/step - reward: -0.2840
# 100 episodes - episode_reward: -28.400 [-100.000, 92.000] - loss: 4.079 - mae: 14.764 - mean_q: 6.204
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: -0.2388
# 100 episodes - episode_reward: -23.880 [-100.000, 90.000] - loss: 4.523 - mae: 15.743 - mean_q: 8.188
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.2674
# done, took 453.003 seconds

# %% [markdown]
# Evaluating the model free DQN

# %%
scores = dqn.test(env, nb_episodes = 100, visualize = False)
print(np.mean(scores.history['episode_reward']))
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: -26.000, steps: 100
# Episode 2: reward: 94.000, steps: 100
# Episode 3: reward: 36.000, steps: 100
# Episode 4: reward: 36.000, steps: 100
# Episode 5: reward: -62.000, steps: 100
# Episode 6: reward: -36.000, steps: 100
# Episode 7: reward: 64.000, steps: 100
# Episode 8: reward: 26.000, steps: 100
# Episode 9: reward: -18.000, steps: 100
# Episode 10: reward: 6.000, steps: 100
# Episode 11: reward: -68.000, steps: 100
# Episode 12: reward: 60.000, steps: 100
# Episode 13: reward: 78.000, steps: 100
# Episode 14: reward: 16.000, steps: 100
# Episode 15: reward: -72.000, steps: 100
# Episode 16: reward: -18.000, steps: 100
# Episode 17: reward: -50.000, steps: 100
# Episode 18: reward: -36.000, steps: 100
# Episode 19: reward: 100.000, steps: 100
# Episode 20: reward: 18.000, steps: 100
# Episode 21: reward: -72.000, steps: 100
# Episode 22: reward: -20.000, steps: 100
# Episode 23: reward: -64.000, steps: 100
# Episode 24: reward: -30.000, steps: 100
# Episode 25: reward: 24.000, steps: 100
# Episode 26: reward: 16.000, steps: 100
# Episode 27: reward: 74.000, steps: 100
# Episode 28: reward: -54.000, steps: 100
# Episode 29: reward: 78.000, steps: 100
# Episode 30: reward: 54.000, steps: 100
# Episode 31: reward: 16.000, steps: 100
# Episode 32: reward: 64.000, steps: 100
# Episode 33: reward: -38.000, steps: 100
# Episode 34: reward: 28.000, steps: 100
# Episode 35: reward: -8.000, steps: 100
# Episode 36: reward: -20.000, steps: 100
# Episode 37: reward: -12.000, steps: 100
# Episode 38: reward: 68.000, steps: 100
# Episode 39: reward: 72.000, steps: 100
# Episode 40: reward: 90.000, steps: 100
# Episode 41: reward: -34.000, steps: 100
# Episode 42: reward: -18.000, steps: 100
# Episode 43: reward: 60.000, steps: 100
# Episode 44: reward: -40.000, steps: 100
# Episode 45: reward: 98.000, steps: 100
# Episode 46: reward: 8.000, steps: 100
# Episode 47: reward: 86.000, steps: 100
# Episode 48: reward: 44.000, steps: 100
# Episode 49: reward: -70.000, steps: 100
# Episode 50: reward: 56.000, steps: 100
# Episode 51: reward: -12.000, steps: 100
# Episode 52: reward: 46.000, steps: 100
# Episode 53: reward: -12.000, steps: 100
# Episode 54: reward: -30.000, steps: 100
# Episode 55: reward: 78.000, steps: 100
# Episode 56: reward: 72.000, steps: 100
# Episode 57: reward: 72.000, steps: 100
# Episode 58: reward: -30.000, steps: 100
# Episode 59: reward: -2.000, steps: 100
# Episode 60: reward: -46.000, steps: 100
# Episode 61: reward: -12.000, steps: 100
# Episode 62: reward: -26.000, steps: 100
# Episode 63: reward: 0.000, steps: 100
# Episode 64: reward: 36.000, steps: 100
# Episode 65: reward: -6.000, steps: 100
# Episode 66: reward: -40.000, steps: 100
# Episode 67: reward: 90.000, steps: 100
# Episode 68: reward: 50.000, steps: 100
# Episode 69: reward: 72.000, steps: 100
# Episode 70: reward: 54.000, steps: 100
# Episode 71: reward: 92.000, steps: 100
# Episode 72: reward: 88.000, steps: 100
# Episode 73: reward: -32.000, steps: 100
# Episode 74: reward: 24.000, steps: 100
# Episode 75: reward: -72.000, steps: 100
# Episode 76: reward: 46.000, steps: 100
# Episode 77: reward: 60.000, steps: 100
# Episode 78: reward: 72.000, steps: 100
# Episode 79: reward: -60.000, steps: 100
# Episode 80: reward: -12.000, steps: 100
# Episode 81: reward: 68.000, steps: 100
# Episode 82: reward: -4.000, steps: 100
# Episode 83: reward: 48.000, steps: 100
# Episode 84: reward: -62.000, steps: 100
# Episode 85: reward: 28.000, steps: 100
# Episode 86: reward: 50.000, steps: 100
# Episode 87: reward: -68.000, steps: 100
# Episode 88: reward: -22.000, steps: 100
# Episode 89: reward: 58.000, steps: 100
# Episode 90: reward: 54.000, steps: 100
# Episode 91: reward: -64.000, steps: 100
# Episode 92: reward: -12.000, steps: 100
# Episode 93: reward: 44.000, steps: 100
# Episode 94: reward: 66.000, steps: 100
# Episode 95: reward: -60.000, steps: 100
# Episode 96: reward: 72.000, steps: 100
# Episode 97: reward: -4.000, steps: 100
# Episode 98: reward: 18.000, steps: 100
# Episode 99: reward: 38.000, steps: 100
# Episode 100: reward: -70.000, steps: 100
# 13.42

# %%
plt.figure(figsize = (20,3.5))
plt.plot(scores.history['episode_reward'])
plt.xlabel('Number of episodes')
plt.ylabel('Reward')
# Out:
# Text(0, 0.5, 'Reward')
